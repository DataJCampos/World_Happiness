# %%
import pandas as pd
import numpy as np

# %%
#create dataframes from 2015-2019

felicidad_2015 = pd.read_csv("data/2015.csv")
felicidad_2016 = pd.read_csv("data/2016.csv")
felicidad_2017 = pd.read_csv("data/2017.csv")
felicidad_2018 = pd.read_csv("data/2018.csv")
felicidad_2019 = pd.read_csv("data/2019.csv")

#concat dataframes into 1 
all_felicidad = pd.concat([felicidad_2015, felicidad_2016, felicidad_2017, felicidad_2018, felicidad_2019], axis=0)
all_felicidad
# Out:
#          Country          Region  Happiness Rank  Happiness Score  \
# 0    Switzerland  Western Europe             1.0            7.587
# 1        Iceland  Western Europe             2.0            7.561
# 2        Denmark  Western Europe             3.0            7.527
# 3         Norway  Western Europe             4.0            7.522
# 4         Canada   North America             5.0            7.427
# ..           ...             ...             ...              ...
# 151          NaN             NaN             NaN              NaN
# 152          NaN             NaN             NaN              NaN
# 153          NaN             NaN             NaN              NaN
# 154          NaN             NaN             NaN              NaN
# 155          NaN             NaN             NaN              NaN
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# ...

# %%
felicidad_2015.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
felicidad_2016.isna().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Lower Confidence Interval        0
# Upper Confidence Interval        0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
felicidad_2017.isna().sum()
# Out:
# Country                          0
# Happiness.Rank                   0
# Happiness.Score                  0
# Whisker.high                     0
# Whisker.low                      0
# Economy..GDP.per.Capita.         0
# Family                           0
# Health..Life.Expectancy.         0
# Freedom                          0
# Generosity                       0
# Trust..Government.Corruption.    0
# Dystopia.Residual                0
# dtype: int64

# %%
felicidad_2018.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       1
# dtype: int64

# %%
felicidad_2019.isna().sum()
# Out:
# Overall rank                    0
# Country or region               0
# Score                           0
# GDP per capita                  0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# dtype: int64

# %% [markdown]
# **In the years 2015-2017, the variable of `Happiness Score` was labeled as such. In the 2018-2019, `Happiness Score` was changed  to `Score`.**

# %%
all_felicidad.isna().sum()
# Out:
# Country                          312
# Region                           467
# Happiness Rank                   467
# Happiness Score                  467
# Standard Error                   624
# Economy (GDP per Capita)         467
# Family                           312
# Health (Life Expectancy)         467
# Freedom                          312
# Trust (Government Corruption)    467
# Generosity                         0
# Dystopia Residual                467
# Lower Confidence Interval        625
# Upper Confidence Interval        625
# Happiness.Rank                   627
# Happiness.Score                  627
# Whisker.high                     627
# Whisker.low                      627
# Economy..GDP.per.Capita.         627
# Health..Life.Expectancy.         627
# Trust..Government.Corruption.    627
# Dystopia.Residual                627
# Overall rank                     470
# Country or region                470
# Score                            470
# ...

# %% [markdown]
# **For this project, the main column names I will keep are the following: `Country`, `Happiness Rank`, `Happiness Score`, `GDP per capita`, `Life Expectancy`, `Generosity`, `Freedom`, `Corrpuation`**

# %% [markdown]
# # *NEXT PART, change column names from each year to match up! Do Pearson Correlation & Linear Regression Model*
